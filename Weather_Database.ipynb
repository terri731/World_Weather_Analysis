# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bc5e223507bb637e1c2d92105db08930

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | sitka
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | sola
# Processing Record 5 of Set 1 | komsomolskiy
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | medeiros neto
# Processing Record 9 of Set 1 | klyuchi
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | husavik
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | yabelo
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | haverhill
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | dickinson
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | abu samrah
# Processing Record 30 of Set 1 | iskateley
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | yankton
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | nur
# Processing Record 37 of Set 1 | dalbandin
# Processing Record 38 of Set 1 | oktyabrskiy
# Processing Record 39 of Set 1 | peniche
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | mount isa
# Processing Record 42 of Set 1 | sangar
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | alihe
# Processing Record 45 of Set 1 | poum
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | tautira
# Processing Record 48 of Set 1 | aalst
# Processing Record 49 of Set 1 | lebanon
# Processing Record 50 of Set 1 | dubbo
# Processing Record 1 of Set 2 | jinchang
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | constitucion
# Processing Record 5 of Set 2 | two rivers
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | canatlan
# Processing Record 8 of Set 2 | hualmay
# Processing Record 9 of Set 2 | wewak
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | oriximina
# Processing Record 13 of Set 2 | awbari
# Processing Record 14 of Set 2 | haicheng
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | piranshahr
# Processing Record 17 of Set 2 | acapulco
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | la rioja
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | ilulissat
# Processing Record 24 of Set 2 | kenai
# Processing Record 25 of Set 2 | sao felix do xingu
# Processing Record 26 of Set 2 | kiunga
# Processing Record 27 of Set 2 | mnogovershinnyy
# Processing Record 28 of Set 2 | yar-sale
# Processing Record 29 of Set 2 | kupang
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | canchungo
# Processing Record 32 of Set 2 | yining
# Processing Record 33 of Set 2 | banda aceh
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | moose factory
# Processing Record 36 of Set 2 | ilinge
# Processing Record 37 of Set 2 | jacala
# Processing Record 38 of Set 2 | tabou
# Processing Record 39 of Set 2 | san andres
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | port-cartier
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | baykit
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | clyde river
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | big rapids
# Processing Record 1 of Set 3 | arroio grande
# Processing Record 2 of Set 3 | tiarei
# Processing Record 3 of Set 3 | copiapo
# Processing Record 4 of Set 3 | rikitea
# Processing Record 5 of Set 3 | srednekolymsk
# Processing Record 6 of Set 3 | aguas buenas
# Processing Record 7 of Set 3 | pakxan
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | sol-iletsk
# Processing Record 10 of Set 3 | hailar
# Processing Record 11 of Set 3 | makakilo city
# Processing Record 12 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 13 of Set 3 | naryan-mar
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | phan thiet
# Processing Record 17 of Set 3 | the valley
# Processing Record 18 of Set 3 | karratha
# Processing Record 19 of Set 3 | nueva helvecia
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | henties bay
# Processing Record 22 of Set 3 | polson
# Processing Record 23 of Set 3 | omsukchan
# Processing Record 24 of Set 3 | tomatlan
# Processing Record 25 of Set 3 | mana
# Processing Record 26 of Set 3 | riviere-au-renard
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 3 | chateaudun
# Processing Record 30 of Set 3 | nicoya
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | mabay
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | itarema
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | chara
# Processing Record 39 of Set 3 | cap malheureux
# Processing Record 40 of Set 3 | kaeo
# Processing Record 41 of Set 3 | santa fe
# Processing Record 42 of Set 3 | vila franca do campo
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | kamenka
# Processing Record 48 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 3 | guerrero negro
# Processing Record 50 of Set 3 | paamiut
# Processing Record 1 of Set 4 | fengkou
# Processing Record 2 of Set 4 | kenora
# Processing Record 3 of Set 4 | taoudenni
# Processing Record 4 of Set 4 | faenza
# Processing Record 5 of Set 4 | trincomalee
# Processing Record 6 of Set 4 | villarrica
# Processing Record 7 of Set 4 | bethal
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | holme
# Processing Record 10 of Set 4 | fasa
# Processing Record 11 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 4 | san quintin
# Processing Record 13 of Set 4 | chernyshevskiy
# Processing Record 14 of Set 4 | gushikawa
# Processing Record 15 of Set 4 | montague
# Processing Record 16 of Set 4 | krasnoselkup
# Processing Record 17 of Set 4 | namatanai
# Processing Record 18 of Set 4 | durusu
# Processing Record 19 of Set 4 | miramar
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | oranjestad
# Processing Record 22 of Set 4 | kibala
# Processing Record 23 of Set 4 | kununurra
# Processing Record 24 of Set 4 | uhlove
# Processing Record 25 of Set 4 | whyalla
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | cortes
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | san carlos de bariloche
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | russell
# Processing Record 32 of Set 4 | punta arenas
# Processing Record 33 of Set 4 | haukipudas
# Processing Record 34 of Set 4 | sisimiut
# Processing Record 35 of Set 4 | barrow
# Processing Record 36 of Set 4 | vicksburg
# Processing Record 37 of Set 4 | berlevag
# Processing Record 38 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 4 | tonekabon
# Processing Record 40 of Set 4 | dongli
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | manta
# Processing Record 43 of Set 4 | potosi
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | fort nelson
# Processing Record 46 of Set 4 | alice springs
# Processing Record 47 of Set 4 | tromso
# Processing Record 48 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 4 | sechura
# Processing Record 50 of Set 4 | qaanaaq
# Processing Record 1 of Set 5 | carballo
# Processing Record 2 of Set 5 | salalah
# Processing Record 3 of Set 5 | rafai
# Processing Record 4 of Set 5 | kulachi
# Processing Record 5 of Set 5 | emerald
# Processing Record 6 of Set 5 | murray bridge
# Processing Record 7 of Set 5 | chalus
# Processing Record 8 of Set 5 | arkalokhorion
# City not found. Skipping...
# Processing Record 9 of Set 5 | asilah
# Processing Record 10 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 5 | olinala
# Processing Record 12 of Set 5 | peterhead
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | havelock
# Processing Record 15 of Set 5 | ullapool
# Processing Record 16 of Set 5 | saint-louis
# Processing Record 17 of Set 5 | asfi
# Processing Record 18 of Set 5 | champerico
# Processing Record 19 of Set 5 | shirokiy
# Processing Record 20 of Set 5 | ouallam
# Processing Record 21 of Set 5 | sorland
# Processing Record 22 of Set 5 | gambela
# Processing Record 23 of Set 5 | beckley
# Processing Record 24 of Set 5 | varnavino
# Processing Record 25 of Set 5 | auki
# Processing Record 26 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 27 of Set 5 | fuyang
# Processing Record 28 of Set 5 | anloga
# Processing Record 29 of Set 5 | san patricio
# Processing Record 30 of Set 5 | kirovskiy
# Processing Record 31 of Set 5 | beloha
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | vestmannaeyjar
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | sur
# Processing Record 37 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 5 | thompson
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | villa rica
# Processing Record 41 of Set 5 | kahului
# Processing Record 42 of Set 5 | hovd
# Processing Record 43 of Set 5 | hohhot
# Processing Record 44 of Set 5 | pailon
# Processing Record 45 of Set 5 | vanimo
# Processing Record 46 of Set 5 | flinders
# Processing Record 47 of Set 5 | cabo san lucas
# Processing Record 48 of Set 5 | kocsord
# Processing Record 49 of Set 5 | manggar
# Processing Record 50 of Set 5 | surin
# Processing Record 1 of Set 6 | marawi
# Processing Record 2 of Set 6 | acarau
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 6 | tongliao
# Processing Record 7 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 6 | sinazongwe
# Processing Record 9 of Set 6 | cherskiy
# Processing Record 10 of Set 6 | khasan
# Processing Record 11 of Set 6 | college
# Processing Record 12 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 6 | gucheng
# Processing Record 14 of Set 6 | dingle
# Processing Record 15 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 6 | coahuayana
# Processing Record 17 of Set 6 | ibra
# Processing Record 18 of Set 6 | eureka
# Processing Record 19 of Set 6 | ketchikan
# Processing Record 20 of Set 6 | klaksvik
# Processing Record 21 of Set 6 | rionero in vulture
# Processing Record 22 of Set 6 | celestun
# Processing Record 23 of Set 6 | camana
# Processing Record 24 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 6 | san cristobal
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | muros
# Processing Record 28 of Set 6 | killybegs
# Processing Record 29 of Set 6 | bosaso
# Processing Record 30 of Set 6 | jiuquan
# Processing Record 31 of Set 6 | miquelon
# Processing Record 32 of Set 6 | meulaboh
# Processing Record 33 of Set 6 | abu dhabi
# Processing Record 34 of Set 6 | taksimo
# Processing Record 35 of Set 6 | redmond
# Processing Record 36 of Set 6 | karasjok
# Processing Record 37 of Set 6 | rawson
# Processing Record 38 of Set 6 | umm lajj
# Processing Record 39 of Set 6 | tongren
# Processing Record 40 of Set 6 | talnakh
# Processing Record 41 of Set 6 | gongzhuling
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | mitsamiouli
# Processing Record 44 of Set 6 | ensenada
# Processing Record 45 of Set 6 | kisangani
# Processing Record 46 of Set 6 | port townsend
# Processing Record 47 of Set 6 | soyo
# Processing Record 48 of Set 6 | krasnovishersk
# Processing Record 49 of Set 6 | hecun
# Processing Record 50 of Set 6 | udachnyy
# Processing Record 1 of Set 7 | reforma
# Processing Record 2 of Set 7 | cap-aux-meules
# Processing Record 3 of Set 7 | berdigestyakh
# Processing Record 4 of Set 7 | labuhan
# Processing Record 5 of Set 7 | owando
# Processing Record 6 of Set 7 | bathsheba
# Processing Record 7 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 7 | saldanha
# Processing Record 9 of Set 7 | sarangani
# Processing Record 10 of Set 7 | saint-pierre
# Processing Record 11 of Set 7 | svetlogorsk
# Processing Record 12 of Set 7 | vila
# Processing Record 13 of Set 7 | kotturu
# Processing Record 14 of Set 7 | santo tomas
# Processing Record 15 of Set 7 | pitimbu
# Processing Record 16 of Set 7 | key largo
# Processing Record 17 of Set 7 | takaka
# Processing Record 18 of Set 7 | guadalupe
# Processing Record 19 of Set 7 | hambantota
# Processing Record 20 of Set 7 | yomou
# Processing Record 21 of Set 7 | boa vista
# Processing Record 22 of Set 7 | gidole
# Processing Record 23 of Set 7 | ode
# Processing Record 24 of Set 7 | aras
# Processing Record 25 of Set 7 | palembang
# Processing Record 26 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | san policarpo
# Processing Record 29 of Set 7 | tutoia
# Processing Record 30 of Set 7 | petervasara
# Processing Record 31 of Set 7 | aquiraz
# Processing Record 32 of Set 7 | paracho
# City not found. Skipping...
# Processing Record 33 of Set 7 | tahe
# Processing Record 34 of Set 7 | mezen
# Processing Record 35 of Set 7 | semey
# Processing Record 36 of Set 7 | sibu
# Processing Record 37 of Set 7 | tashtagol
# Processing Record 38 of Set 7 | wagar
# Processing Record 39 of Set 7 | kilmez
# City not found. Skipping...
# Processing Record 40 of Set 7 | katsuura
# Processing Record 41 of Set 7 | nelson bay
# Processing Record 42 of Set 7 | pisco
# Processing Record 43 of Set 7 | korla
# Processing Record 44 of Set 7 | salym
# Processing Record 45 of Set 7 | salinopolis
# Processing Record 46 of Set 7 | sidi ali
# Processing Record 47 of Set 7 | aklavik
# Processing Record 48 of Set 7 | nisia floresta
# Processing Record 49 of Set 7 | kjollefjord
# Processing Record 50 of Set 7 | los llanos de aridane
# Processing Record 1 of Set 8 | pevek
# Processing Record 2 of Set 8 | newport
# Processing Record 3 of Set 8 | fairbanks
# Processing Record 4 of Set 8 | rorvik
# Processing Record 5 of Set 8 | whitianga
# Processing Record 6 of Set 8 | bontang
# Processing Record 7 of Set 8 | vostok
# Processing Record 8 of Set 8 | roebourne
# Processing Record 9 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 8 | huarmey
# Processing Record 11 of Set 8 | moroni
# Processing Record 12 of Set 8 | moskovskiy
# Processing Record 13 of Set 8 | mattru
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | coihaique
# Processing Record 16 of Set 8 | goure
# Processing Record 17 of Set 8 | wilmington
# Processing Record 18 of Set 8 | kamen-na-obi
# Processing Record 19 of Set 8 | karaj
# Processing Record 20 of Set 8 | kerrville
# Processing Record 21 of Set 8 | bereda
# Processing Record 22 of Set 8 | irbit
# Processing Record 23 of Set 8 | bolivar
# Processing Record 24 of Set 8 | pochutla
# Processing Record 25 of Set 8 | buala
# Processing Record 26 of Set 8 | tiksi
# Processing Record 27 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 28 of Set 8 | olafsvik
# Processing Record 29 of Set 8 | arman
# Processing Record 30 of Set 8 | road town
# Processing Record 31 of Set 8 | khilok
# Processing Record 32 of Set 8 | dunedin
# Processing Record 33 of Set 8 | lahij
# Processing Record 34 of Set 8 | lincoln
# Processing Record 35 of Set 8 | marovoay
# Processing Record 36 of Set 8 | sohag
# Processing Record 37 of Set 8 | rundu
# Processing Record 38 of Set 8 | naze
# Processing Record 39 of Set 8 | jertih
# Processing Record 40 of Set 8 | tumalaytay
# Processing Record 41 of Set 8 | sabang
# Processing Record 42 of Set 8 | sinnamary
# Processing Record 43 of Set 8 | yukamenskoye
# Processing Record 44 of Set 8 | batsfjord
# Processing Record 45 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 8 | vila velha
# Processing Record 47 of Set 8 | vata de jos
# Processing Record 48 of Set 8 | les cayes
# Processing Record 49 of Set 8 | bambari
# Processing Record 50 of Set 8 | uk
# City not found. Skipping...
# Processing Record 1 of Set 9 | okha
# Processing Record 2 of Set 9 | aykhal
# Processing Record 3 of Set 9 | mao
# Processing Record 4 of Set 9 | avera
# Processing Record 5 of Set 9 | srandakan
# Processing Record 6 of Set 9 | mecca
# Processing Record 7 of Set 9 | seoul
# Processing Record 8 of Set 9 | anadyr
# Processing Record 9 of Set 9 | lagunas
# Processing Record 10 of Set 9 | alofi
# Processing Record 11 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 9 | sobolevo
# Processing Record 13 of Set 9 | serenje
# Processing Record 14 of Set 9 | jasper
# Processing Record 15 of Set 9 | iquique
# Processing Record 16 of Set 9 | isangel
# Processing Record 17 of Set 9 | lagoa
# Processing Record 18 of Set 9 | horsham
# Processing Record 19 of Set 9 | sao joao da barra
# Processing Record 20 of Set 9 | chiang klang
# Processing Record 21 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | palenque
# Processing Record 23 of Set 9 | ouadda
# Processing Record 24 of Set 9 | denpasar
# Processing Record 25 of Set 9 | lompoc
# Processing Record 26 of Set 9 | micheweni
# Processing Record 27 of Set 9 | nouadhibou
# Processing Record 28 of Set 9 | san miguel
# Processing Record 29 of Set 9 | ballina
# Processing Record 30 of Set 9 | groditz
# City not found. Skipping...
# Processing Record 31 of Set 9 | shache
# Processing Record 32 of Set 9 | kachiry
# Processing Record 33 of Set 9 | ambilobe
# Processing Record 34 of Set 9 | sattenapalle
# Processing Record 35 of Set 9 | balabac
# Processing Record 36 of Set 9 | alim
# Processing Record 37 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 9 | armizonskoye
# Processing Record 39 of Set 9 | upernavik
# Processing Record 40 of Set 9 | sertania
# Processing Record 41 of Set 9 | la paz
# Processing Record 42 of Set 9 | chilca
# Processing Record 43 of Set 9 | ostrovnoy
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 9 | tunggol
# Processing Record 47 of Set 9 | mikun
# Processing Record 48 of Set 9 | darab
# Processing Record 49 of Set 9 | lubango
# Processing Record 50 of Set 9 | tuatapere
# Processing Record 1 of Set 10 | weiser
# Processing Record 2 of Set 10 | paka
# Processing Record 3 of Set 10 | leningradskiy
# Processing Record 4 of Set 10 | thinadhoo
# Processing Record 5 of Set 10 | yulara
# Processing Record 6 of Set 10 | ayorou
# Processing Record 7 of Set 10 | temirtau
# Processing Record 8 of Set 10 | caxito
# Processing Record 9 of Set 10 | touros
# Processing Record 10 of Set 10 | tete
# Processing Record 11 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 10 | kudahuvadhoo
# Processing Record 13 of Set 10 | palimbang
# Processing Record 14 of Set 10 | vestmanna
# Processing Record 15 of Set 10 | botwood
# Processing Record 16 of Set 10 | kretinga
# Processing Record 17 of Set 10 | oromocto
# Processing Record 18 of Set 10 | kilrush
# Processing Record 19 of Set 10 | codrington
# Processing Record 20 of Set 10 | egvekinot
# Processing Record 21 of Set 10 | waw
# Processing Record 22 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 10 | lagos
# Processing Record 24 of Set 10 | kangaatsiaq
# Processing Record 25 of Set 10 | angra
# City not found. Skipping...
# Processing Record 26 of Set 10 | kavieng
# Processing Record 27 of Set 10 | jacmel
# Processing Record 28 of Set 10 | santander
# Processing Record 29 of Set 10 | okhotsk
# Processing Record 30 of Set 10 | daru
# Processing Record 31 of Set 10 | richmond
# Processing Record 32 of Set 10 | kajaani
# Processing Record 33 of Set 10 | narsaq
# Processing Record 34 of Set 10 | port hardy
# Processing Record 35 of Set 10 | senno
# Processing Record 36 of Set 10 | pemangkat
# Processing Record 37 of Set 10 | norman wells
# Processing Record 38 of Set 10 | campo maior
# Processing Record 39 of Set 10 | rapid valley
# Processing Record 40 of Set 10 | berezovyy
# Processing Record 41 of Set 10 | juegang
# Processing Record 42 of Set 10 | roald
# Processing Record 43 of Set 10 | nan
# Processing Record 44 of Set 10 | agadez
# Processing Record 45 of Set 10 | port-gentil
# Processing Record 46 of Set 10 | manado
# Processing Record 47 of Set 10 | bardiyah
# Processing Record 48 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 49 of Set 10 | sampit
# Processing Record 50 of Set 10 | amet
# Processing Record 1 of Set 11 | scarborough
# Processing Record 2 of Set 11 | hawalli
# Processing Record 3 of Set 11 | andra
# Processing Record 4 of Set 11 | la grande
# Processing Record 5 of Set 11 | nampula
# Processing Record 6 of Set 11 | luderitz
# Processing Record 7 of Set 11 | pacific grove
# Processing Record 8 of Set 11 | morganton
# Processing Record 9 of Set 11 | miraflores
# Processing Record 10 of Set 11 | swan river
# Processing Record 11 of Set 11 | kondinskoye
# Processing Record 12 of Set 11 | sadovo
# Processing Record 13 of Set 11 | dombarovskiy
# Processing Record 14 of Set 11 | morondava
# Processing Record 15 of Set 11 | deneysville
# Processing Record 16 of Set 11 | hopkinsville
# Processing Record 17 of Set 11 | batemans bay
# Processing Record 18 of Set 11 | palm coast
# Processing Record 19 of Set 11 | kilifi
# Processing Record 20 of Set 11 | sri aman
# Processing Record 21 of Set 11 | orje
# Processing Record 22 of Set 11 | cidreira
# Processing Record 23 of Set 11 | diu
# Processing Record 24 of Set 11 | tigil
# Processing Record 25 of Set 11 | saint george
# Processing Record 26 of Set 11 | vikramasingapuram
# Processing Record 27 of Set 11 | serowe
# Processing Record 28 of Set 11 | sedkyrkeshch
# Processing Record 29 of Set 11 | orcopampa
# Processing Record 30 of Set 11 | sambava
# Processing Record 31 of Set 11 | talcahuano
# Processing Record 32 of Set 11 | waingapu
# Processing Record 33 of Set 11 | ordubad
# Processing Record 34 of Set 11 | durban
# Processing Record 35 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 11 | tecoanapa
# Processing Record 37 of Set 11 | tandil
# Processing Record 38 of Set 11 | dicabisagan
# Processing Record 39 of Set 11 | kodinsk
# Processing Record 40 of Set 11 | antofagasta
# Processing Record 41 of Set 11 | coihueco
# Processing Record 42 of Set 11 | mitu
# Processing Record 43 of Set 11 | ahipara
# Processing Record 44 of Set 11 | santa cruz
# Processing Record 45 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 11 | yebaishou
# Processing Record 47 of Set 11 | sioux lookout
# Processing Record 48 of Set 11 | lorengau
# Processing Record 49 of Set 11 | shubarshi
# Processing Record 50 of Set 11 | penzance
# Processing Record 1 of Set 12 | gat
# Processing Record 2 of Set 12 | barrhead
# Processing Record 3 of Set 12 | pollachi
# Processing Record 4 of Set 12 | upata
# Processing Record 5 of Set 12 | los algarrobos
# Processing Record 6 of Set 12 | nyurba
# Processing Record 7 of Set 12 | divnomorskoye
# Processing Record 8 of Set 12 | sibiti
# Processing Record 9 of Set 12 | suruc
# Processing Record 10 of Set 12 | noshiro
# Processing Record 11 of Set 12 | te anau
# Processing Record 12 of Set 12 | kieta
# Processing Record 13 of Set 12 | namibe
# Processing Record 14 of Set 12 | vanavara
# Processing Record 15 of Set 12 | bengkulu
# Processing Record 16 of Set 12 | albert lea
# Processing Record 17 of Set 12 | praya
# Processing Record 18 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 12 | kirakira
# Processing Record 20 of Set 12 | turukhansk
# Processing Record 21 of Set 12 | tarare
# Processing Record 22 of Set 12 | maldonado
# Processing Record 23 of Set 12 | kiruna
# Processing Record 24 of Set 12 | tabas
# Processing Record 25 of Set 12 | illapel
# Processing Record 26 of Set 12 | dongsheng
# Processing Record 27 of Set 12 | mala vyska
# Processing Record 28 of Set 12 | bogo
# Processing Record 29 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 12 | mackay
# Processing Record 31 of Set 12 | severnoye
# Processing Record 32 of Set 12 | beringovskiy
# Processing Record 33 of Set 12 | tateyama
# Processing Record 34 of Set 12 | rancho palos verdes
# Processing Record 35 of Set 12 | itoman
# Processing Record 36 of Set 12 | sault sainte marie
# Processing Record 37 of Set 12 | zelenoborsk
# Processing Record 38 of Set 12 | aars
# Processing Record 39 of Set 12 | kungurtug
# Processing Record 40 of Set 12 | sibolga
# Processing Record 41 of Set 12 | riohacha
# Processing Record 42 of Set 12 | tarakan
# Processing Record 43 of Set 12 | kaitangata
# Processing Record 44 of Set 12 | adrar
# Processing Record 45 of Set 12 | nanakuli
# Processing Record 46 of Set 12 | ambon
# Processing Record 47 of Set 12 | cortez
# Processing Record 48 of Set 12 | kihei
# Processing Record 49 of Set 12 | sabratah
# Processing Record 50 of Set 12 | irara
# Processing Record 1 of Set 13 | mizdah
# Processing Record 2 of Set 13 | lavrentiya
# Processing Record 3 of Set 13 | casablanca
# Processing Record 4 of Set 13 | manaure
# Processing Record 5 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 13 | harlingen
# Processing Record 7 of Set 13 | ulladulla
# Processing Record 8 of Set 13 | idenao
# Processing Record 9 of Set 13 | brindisi
# Processing Record 10 of Set 13 | lastoursville
# Processing Record 11 of Set 13 | malmyzh
# Processing Record 12 of Set 13 | sao miguel do araguaia
# Processing Record 13 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 13 | tommot
# Processing Record 15 of Set 13 | northam
# Processing Record 16 of Set 13 | aguada de pasajeros
# Processing Record 17 of Set 13 | sonamura
# Processing Record 18 of Set 13 | hervey bay
# Processing Record 19 of Set 13 | trebinje
# Processing Record 20 of Set 13 | nantucket
# Processing Record 21 of Set 13 | siocon
# Processing Record 22 of Set 13 | hamilton
# Processing Record 23 of Set 13 | leh
# Processing Record 24 of Set 13 | aurillac
# Processing Record 25 of Set 13 | tombouctou
# Processing Record 26 of Set 13 | nurota
# Processing Record 27 of Set 13 | gushi
# Processing Record 28 of Set 13 | alac
# Processing Record 29 of Set 13 | bandarbeyla
# Processing Record 30 of Set 13 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 31 of Set 13 | hope
# Processing Record 32 of Set 13 | abu kamal
# Processing Record 33 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 13 | sao goncalo do amarante
# Processing Record 35 of Set 13 | lazurne
# Processing Record 36 of Set 13 | lebyazhye
# Processing Record 37 of Set 13 | neepawa
# Processing Record 38 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 13 | oskarshamn
# Processing Record 40 of Set 13 | jiwani
# Processing Record 41 of Set 13 | matraterenye
# Processing Record 42 of Set 13 | san francisco
# Processing Record 43 of Set 13 | ayan
# Processing Record 44 of Set 13 | raposa
# Processing Record 45 of Set 13 | qianjiang
# Processing Record 46 of Set 13 | catamarca
# Processing Record 47 of Set 13 | lakatoro
# Processing Record 48 of Set 13 | yate
# Processing Record 49 of Set 13 | tall kayf
# Processing Record 50 of Set 13 | springfield
# Processing Record 1 of Set 14 | shelburne
# Processing Record 2 of Set 14 | diamantina
# Processing Record 3 of Set 14 | de aar
# Processing Record 4 of Set 14 | yabrud
# Processing Record 5 of Set 14 | tessalit
# Processing Record 6 of Set 14 | bonnyville
# Processing Record 7 of Set 14 | pasighat
# Processing Record 8 of Set 14 | ukiah
# Processing Record 9 of Set 14 | bambanglipuro
# Processing Record 10 of Set 14 | florianopolis
# Processing Record 11 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 14 | dali
# Processing Record 13 of Set 14 | halifax
# Processing Record 14 of Set 14 | aneho
# Processing Record 15 of Set 14 | taywarah
# Processing Record 16 of Set 14 | yarmouth
# Processing Record 17 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 14 | vidra
# Processing Record 19 of Set 14 | waddan
# Processing Record 20 of Set 14 | zolotyy potik
# Processing Record 21 of Set 14 | minas de barroteran
# Processing Record 22 of Set 14 | cururupu
# Processing Record 23 of Set 14 | skelleftea
# Processing Record 24 of Set 14 | cangzhou
# Processing Record 25 of Set 14 | cervo
# Processing Record 26 of Set 14 | kristiansund
# Processing Record 27 of Set 14 | japura
# Processing Record 28 of Set 14 | christchurch
# Processing Record 29 of Set 14 | taltal
# Processing Record 30 of Set 14 | bac lieu
# Processing Record 31 of Set 14 | necochea
# Processing Record 32 of Set 14 | rafael lucio
# Processing Record 33 of Set 14 | ewa beach
# Processing Record 34 of Set 14 | viedma
# Processing Record 35 of Set 14 | derzhavinsk
# Processing Record 36 of Set 14 | wanderlandia
# City not found. Skipping...
# Processing Record 37 of Set 14 | kapuskasing
# Processing Record 38 of Set 14 | george town
# Processing Record 39 of Set 14 | belmonte
# Processing Record 40 of Set 14 | polunochnoye
# Processing Record 41 of Set 14 | fontaine
# Processing Record 42 of Set 14 | ancud
# Processing Record 43 of Set 14 | boda
# Processing Record 44 of Set 14 | chicama
# Processing Record 45 of Set 14 | yakeshi
# Processing Record 46 of Set 14 | oksovskiy
# Processing Record 47 of Set 14 | fuerte olimpo
# Processing Record 48 of Set 14 | mbalmayo
# Processing Record 49 of Set 14 | gazli
# Processing Record 50 of Set 14 | nizhniy kuranakh
# Processing Record 1 of Set 15 | biltine
# Processing Record 2 of Set 15 | iralaya
# Processing Record 3 of Set 15 | kichmengskiy gorodok
# Processing Record 4 of Set 15 | binzhou
# Processing Record 5 of Set 15 | great yarmouth
# Processing Record 6 of Set 15 | loding
# Processing Record 7 of Set 15 | pampa
# Processing Record 8 of Set 15 | luganville
# Processing Record 9 of Set 15 | phanom sarakham
# Processing Record 10 of Set 15 | yenagoa
# Processing Record 11 of Set 15 | phangnga
# Processing Record 12 of Set 15 | lavumisa
# Processing Record 13 of Set 15 | burica
# City not found. Skipping...
# Processing Record 14 of Set 15 | richards bay
# Processing Record 15 of Set 15 | santa helena
# Processing Record 16 of Set 15 | saint-augustin
# Processing Record 17 of Set 15 | hlobyne
# Processing Record 18 of Set 15 | cockburn town
# Processing Record 19 of Set 15 | manzanillo
# Processing Record 20 of Set 15 | cayenne
# Processing Record 21 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 15 | shenjiamen
# Processing Record 24 of Set 15 | severo-yeniseyskiy
# Processing Record 25 of Set 15 | xai-xai
# Processing Record 26 of Set 15 | ubud
# Processing Record 27 of Set 15 | almeria
# Processing Record 28 of Set 15 | saurimo
# Processing Record 29 of Set 15 | esna
# Processing Record 30 of Set 15 | vao
# Processing Record 31 of Set 15 | puerto baquerizo moreno
# Processing Record 32 of Set 15 | magistralnyy
# Processing Record 33 of Set 15 | tchibanga
# Processing Record 34 of Set 15 | loa janan
# Processing Record 35 of Set 15 | cabadiangan
# Processing Record 36 of Set 15 | murgab
# Processing Record 37 of Set 15 | imst
# Processing Record 38 of Set 15 | lenine
# Processing Record 39 of Set 15 | schleiden
# Processing Record 40 of Set 15 | brvenica
# Processing Record 41 of Set 15 | blagoyevo
# Processing Record 42 of Set 15 | dhidhdhoo
# Processing Record 43 of Set 15 | samarai
# Processing Record 44 of Set 15 | mulege
# Processing Record 45 of Set 15 | beisfjord
# Processing Record 46 of Set 15 | riverton
# Processing Record 47 of Set 15 | talaya
# Processing Record 48 of Set 15 | charters towers
# Processing Record 49 of Set 15 | byron bay
# Processing Record 50 of Set 15 | zyryanka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mahebourg      MU -20.4081   57.7000     74.25        72          78
# 1          Sitka      US  57.0531 -135.3300     48.09        66          90
# 2           Sola      VU -13.8833  167.5500     81.12        76          10
# 3   Komsomolskiy      UZ  40.4272   71.7189     38.12        70           0
# 4         Albany      US  42.6001  -73.9662     47.57        77          83
# 5      Jamestown      US  42.0970  -79.2353     44.29        95          75
# 6  Medeiros Neto      BR -17.3739  -40.2206     69.82        94           9
# 7        Klyuchi      RU  52.2667   79.1667     44.65        69          56
# 8        Ushuaia      AR -54.8000  -68.3000     33.46        86          75
# 9   Puerto Ayora      EC  -0.7393  -90.3518     69.08        89          85
#
#    Wind Speed Current Description
# 0       11.95       broken clouds
# 1       11.50       moderate rain
# 2       16.11           clear sky
# 3        6.91           clear sky
# 4        1.01       broken clouds
# 5        1.99       broken clouds
# 6        4.32           clear sky
# 7       15.88       broken clouds
# 8       12.66          light snow
# 9        7.94     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_df.count()
# Out:
# City                   697
# Country                697
# Lat                    697
# Lng                    697
# Max Temp               697
# Humidity               697
# Cloudiness             697
# Wind Speed             697
# Current Description    697
# dtype: int64
